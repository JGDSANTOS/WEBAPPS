# %% [markdown]
# IMPORT THE LIBRARYS TO USE THEM

# %%
import pandas as pd
import polars as pl

# %% [markdown]
# Read Data in Pandas library

# %%
DB_LogisticPD = pd.read_excel(r"C:\Users\jgdsantos\OneDrive\Aralco\5. Material Complementar\Projetos\DB_Logistical\BD_Logistica.xlsx")
DB_LogisticPD.head(10)
# Out:
#   Nº Pedido             Cliente - Motorista Data Emissão Pedido  \
# 0        A3            WALMART-FELIPE SILVA          2019-01-27
# 1        A4   MAGAZINE LUIZA-TÚLIO SILVEIRA          2019-01-28
# 2        A7  MAGAZINE LUIZA-VALDIR ESPINOSA          2019-02-04
# 3       A12     MAGAZINE LUIZA-MARCOS LEROY          2019-02-18
# 4       A15             WALMART-LUIZ PARDAL          2019-02-21
# 5       A16              WALMART-JOÃO GOMES          2019-02-23
# 6       A17              WALMART-JOÃO GOMES          2019-02-24
# 7       A20  MAGAZINE LUIZA-VALDIR ESPINOSA          2019-02-26
# 8       A22      AMERICANAS-VALDIR ESPINOSA          2019-03-01
# 9       A23         AMERICANAS-MARCOS LEROY          2019-03-02
#
#   Data Entrega Prevista Destino  Itens  R$ Faturados Saída para Entrega  \
# 0            2019-02-06      SP      3         139.5         2019-01-29
# 1            2019-02-07      RJ      4         134.4         2019-02-09
# ...

# %%
type(DB_LogisticPD)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Read Data in Polars library

# %%
DB_LogisticPL = pl.read_excel(r"C:\Users\jgdsantos\OneDrive\Aralco\5. Material Complementar\Projetos\DB_Logistical\BD_Logistica.xlsx"
    )

print(DB_LogisticPL)
# Out:
# shape: (4_282, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Nº Pedido ┆ Cliente - ┆ Data      ┆ Data      ┆ … ┆ Qtd       ┆ Mot.      ┆ Dias Para ┆ Status   │
# │ ---       ┆ Motorista ┆ Emissão   ┆ Entrega   ┆   ┆ Devolução ┆ Devolução ┆ Entrega   ┆ ---      │
# │ str       ┆ ---       ┆ Pedido    ┆ Prevista  ┆   ┆ ---       ┆ ---       ┆ ---       ┆ str      │
# │           ┆ str       ┆ ---       ┆ ---       ┆   ┆ i64       ┆ str       ┆ i64       ┆          │
# │           ┆           ┆ date      ┆ date      ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ A3        ┆ WALMART-F ┆ 2019-01-2 ┆ 2019-02-0 ┆ … ┆ 0         ┆ S/        ┆ 7         ┆ No Prazo │
# │           ┆ ELIPE     ┆ 7         ┆ 6         ┆   ┆           ┆ Devolu.   ┆           ┆          │
# ...

# %%
type(DB_LogisticPL)
# Out:
# polars.dataframe.frame.DataFrame
